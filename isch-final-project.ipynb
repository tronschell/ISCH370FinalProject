# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint

# %%
c = twint.Config()
c.Search = "Decentraland"
c.Store_csv = True
c.Lang = 'en'
c.Since = "2021-03-01"
c.Verified = True
c.Output = "ISCHDATA-Decentraland.csv"

twint.run.Search(c)
# Out:
# 1502824497048657923 2022-03-12 20:50:55 -0400 <sandy_carter> And we love that @decentraland gave us at @UnstoppableWoW3 to build our HQ!!! So grateful!!!
# 1502817438492209157 2022-03-12 20:22:52 -0400 <EverRise> @Z_Humphries @Shibtoken @ethereum @Bitcoin @cryptocom @GoGalaGames @solana @Cardano @decentraland @0xPolygon @TheSandboxGame @hedera We’ll be on this list one day 🤫
# 1502794431157653504 2022-03-12 18:51:27 -0400 <CryptoKaijuIO> @conlan Just sent you the lovely @decentraland wearable version, thanks again for believing in us and allowing us on the platform, loved it !!!
# 1502786263434162179 2022-03-12 18:19:00 -0400 <marketingdive> Fans can explore the Integra's features in @Acura of Decentraland, play a racing game and browse a new wearable collection designed by an NFT artist.  https://t.co/bKlBnmlOeZ
# ...
